# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(np.random.randn(9),index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],[1, 2, 3, 1, 3, 1, 2, 2, 3]])

# %%
data
# Out:
# a  1   -0.743338
#    2   -0.407244
#    3    1.337042
# b  1    0.998709
#    3   -1.200749
# c  1   -0.038601
#    2    1.837348
# d  2   -0.980658
#    3   -0.986187
# dtype: float64

# %%
data.unstack().stack()
# Out:
# a  1   -0.743338
#    2   -0.407244
#    3    1.337042
# b  1    0.998709
#    3   -1.200749
# c  1   -0.038601
#    2    1.837348
# d  2   -0.980658
#    3   -0.986187
# dtype: float64

# %%
data['a']
# Out:
# 1   -0.743338
# 2   -0.407244
# 3    1.337042
# dtype: float64

# %%
data.loc['a']
# Out:
# 1   -0.743338
# 2   -0.407244
# 3    1.337042
# dtype: float64

# %%
data.loc[:,1]
# Out:
# a   -0.743338
# b    0.998709
# c   -0.038601
# dtype: float64

# %%
data.loc[['a','b']]
# Out:
# a  1   -0.743338
#    2   -0.407244
#    3    1.337042
# b  1    0.998709
#    3   -1.200749
# dtype: float64

# %%
! git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
df=pd.read_csv('/content/Practicum_Datasets/world_cities_air_water_quality.csv')
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
columns=['City',	"Region",	"Country",	"AirQuality",	"WaterPollution"]
df.columns=columns

# %%
df.head()
# Out:
#                City                   Region                      Country  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df['Region']=df['Region'].map(lambda x:x.replace('"',''))

# %%
df['Country']=df['Country'].map(lambda x:x.replace('"',''))

# %%
df.head()
# Out:
#                City                 Region                    Country  \
# 0     New York City               New York   United States of America
# 1  Washington, D.C.   District of Columbia   United States of America
# 2     San Francisco             California   United States of America
# 3            Berlin                                           Germany
# 4       Los Angeles             California   United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df.to_csv('updated_daaset.csv',index=False)

# %%
df[df['Country']=='Germany']
# Out:
# Empty DataFrame
# Columns: [City, Region, Country, AirQuality, WaterPollution]
# Index: []

# %%
df['Country'][2]
# Out:
# ' United States of America'

# %%
df['Country']=df['Country'].map(lambda x:x.strip())

# %%
df[df['Country']=='Germany']
# Out:
#                         City                   Region  Country  AirQuality  \
# 3                     Berlin                           Germany   62.364130
# 28                   Cologne   North Rhine-Westphalia  Germany   60.714286
# 40                      Bonn   North Rhine-Westphalia  Germany   82.812500
# 52                 Heilbronn        Baden-Wurttemberg  Germany   80.000000
# 76                    Aachen   North Rhine-Westphalia  Germany   70.454545
# ...                      ...                      ...      ...         ...
# 2693             Bad Waldsee        Baden-Wurttemberg  Germany  100.000000
# 2714  Weilheim in Oberbayern                  Bavaria  Germany  100.000000
# 2727                  Buckow              Brandenburg  Germany   87.500000
# 3942                  Erfurt                Thuringia  Germany   85.000000
# 3943  Garmisch-Partenkirchen                  Bavaria  Germany  100.000000
#
#       WaterPollution   County
# 3          28.612717  Germany
# ...

# %%
df[df['Country']=='Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution      County
# 21  Tashkent         Uzbekistan   56.451613       49.166667  Uzbekistan

# %%
df.to_csv('updated_dataset.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3963, step=1)

# %%
df1=pd.pivot_table(df,index=['Country','City'])
df1
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df1.loc[['Uzbekistan', 'Germany', 'Tajikistan']]
# Out:
#                       AirQuality  WaterPollution
# Country    City
# Uzbekistan Tashkent    56.451613       49.166667
# Germany    Aachen      70.454545       17.857143
#            Aalen       87.500000       50.000000
#            Abensberg  100.000000       50.000000
#            Amberg     100.000000       50.000000
# ...                          ...             ...
#            Wolfsburg   96.875000        0.000000
#            Worms       60.000000      100.000000
#            Wuppertal   90.000000        0.000000
#            Zwickau     75.000000       50.000000
# Tajikistan Dushanbe    41.666667       61.111111
#
# [126 rows x 2 columns]

# %%
df2=df1.copy()

# %%
df2['Airpollution']=100-df["AirQuality"]
df2['WaterQuality']=100-df["WaterPollution"]

# %%
data=pd.DataFrame(df2.values,index=df2.index,columns=[['Air','Air','Water','Water'],['AirQuality','Airpollution','Waterquality','WaterPollution']])

# %%
data
# Out:
#                              Air                     Water
#                       AirQuality Airpollution Waterquality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000          NaN            NaN
#             Farah     100.000000     0.000000          NaN            NaN
#             Herat      43.750000    31.250000          NaN            NaN
#             Kabul      18.421053    81.060606          NaN            NaN
#             Kandahar    0.000000    75.000000          NaN            NaN
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000          NaN            NaN
# Zimbabwe    Bindura    50.000000    75.000000          NaN            NaN
#             Bulawayo   67.857143    71.428571          NaN            NaN
#             Harare     38.461538    87.500000          NaN            NaN
#             Masvingo   25.000000    62.500000          NaN            NaN
#
# ...

# %%
data['Air']
# Out:
#                       AirQuality  Airpollution
# Country     City
# Afghanistan Andkhoy    50.000000     50.000000
#             Farah     100.000000      0.000000
#             Herat      43.750000     31.250000
#             Kabul      18.421053     81.060606
#             Kandahar    0.000000     75.000000
# ...                          ...           ...
# Zambia      Mansa      75.000000     25.000000
# Zimbabwe    Bindura    50.000000     75.000000
#             Bulawayo   67.857143     71.428571
#             Harare     38.461538     87.500000
#             Masvingo   25.000000     62.500000
#
# [3895 rows x 2 columns]

# %%
data
# Out:
#                              Air                     Water
#                       AirQuality Airpollution Waterquality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000          NaN            NaN
#             Farah     100.000000     0.000000          NaN            NaN
#             Herat      43.750000    31.250000          NaN            NaN
#             Kabul      18.421053    81.060606          NaN            NaN
#             Kandahar    0.000000    75.000000          NaN            NaN
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000          NaN            NaN
# Zimbabwe    Bindura    50.000000    75.000000          NaN            NaN
#             Bulawayo   67.857143    71.428571          NaN            NaN
#             Harare     38.461538    87.500000          NaN            NaN
#             Masvingo   25.000000    62.500000          NaN            NaN
#
# ...

# %%
data.columns.names=['Object','Info']

# %%
data
# Out:
# Object                       Air                     Water
# Info                  AirQuality Airpollution Waterquality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000          NaN            NaN
#             Farah     100.000000     0.000000          NaN            NaN
#             Herat      43.750000    31.250000          NaN            NaN
#             Kabul      18.421053    81.060606          NaN            NaN
#             Kandahar    0.000000    75.000000          NaN            NaN
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000          NaN            NaN
# Zimbabwe    Bindura    50.000000    75.000000          NaN            NaN
#             Bulawayo   67.857143    71.428571          NaN            NaN
#             Harare     38.461538    87.500000          NaN            NaN
#             Masvingo   25.000000    62.500000          NaN            NaN
#
# ...

# %%
data.index.names
# Out:
# FrozenList(['Country', 'City'])

# %%
data.swaplevel('Country','City')
# Out:
# Object                       Air                     Water
# Info                  AirQuality Airpollution Waterquality WaterPollution
# City     Country
# Andkhoy  Afghanistan   50.000000    50.000000          NaN            NaN
# Farah    Afghanistan  100.000000     0.000000          NaN            NaN
# Herat    Afghanistan   43.750000    31.250000          NaN            NaN
# Kabul    Afghanistan   18.421053    81.060606          NaN            NaN
# Kandahar Afghanistan    0.000000    75.000000          NaN            NaN
# ...                          ...          ...          ...            ...
# Mansa    Zambia        75.000000    25.000000          NaN            NaN
# Bindura  Zimbabwe      50.000000    75.000000          NaN            NaN
# Bulawayo Zimbabwe      67.857143    71.428571          NaN            NaN
# Harare   Zimbabwe      38.461538    87.500000          NaN            NaN
# Masvingo Zimbabwe      25.000000    62.500000          NaN            NaN
#
# ...

# %%
data
# Out:
# Object                       Air                     Water
# Info                  AirQuality Airpollution Waterquality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000          NaN            NaN
#             Farah     100.000000     0.000000          NaN            NaN
#             Herat      43.750000    31.250000          NaN            NaN
#             Kabul      18.421053    81.060606          NaN            NaN
#             Kandahar    0.000000    75.000000          NaN            NaN
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000          NaN            NaN
# Zimbabwe    Bindura    50.000000    75.000000          NaN            NaN
#             Bulawayo   67.857143    71.428571          NaN            NaN
#             Harare     38.461538    87.500000          NaN            NaN
#             Masvingo   25.000000    62.500000          NaN            NaN
#
# ...

# %%
data.sort_index(level=0,ascending=False)
# Out:
# Object                       Air                     Water
# Info                  AirQuality Airpollution Waterquality WaterPollution
# Country     City
# Zimbabwe    Masvingo   25.000000    62.500000          NaN            NaN
#             Harare     38.461538    87.500000          NaN            NaN
#             Bulawayo   67.857143    71.428571          NaN            NaN
#             Bindura    50.000000    75.000000          NaN            NaN
# Zambia      Mansa      75.000000    25.000000          NaN            NaN
# ...                          ...          ...          ...            ...
# Afghanistan Kandahar    0.000000    75.000000          NaN            NaN
#             Kabul      18.421053    81.060606          NaN            NaN
#             Herat      43.750000    31.250000          NaN            NaN
#             Farah     100.000000     0.000000          NaN            NaN
#             Andkhoy    50.000000    50.000000          NaN            NaN
#
# ...
